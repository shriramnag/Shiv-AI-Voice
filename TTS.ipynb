# %%
#@title 🚩 शिव AI - डैशबोर्ड { display-mode: "form" }
from IPython.display import HTML, display

html_code = '''<div style="background-color:#0d1117;padding:30px;border-radius:20px;text-align:center;border:2px solid #2ecc71;font-family:Arial,sans-serif;box-shadow:0 10px 30px rgba(0,0,0,0.6);max-width:750px;margin:0 auto">
  <div style="display:flex;justify-content:center;margin-bottom:20px">
    <a href="https://www.youtube.com/@PAISAWALA20" target="_blank">
      <img src="https://raw.githubusercontent.com/shriramnag/Aivoicebox/main/IMG_20260307_091759.jpg"
           alt="PAISAWALA" onerror="this.src=\'https://via.placeholder.com/700x180/000/0f0?text=PAISAWALA\'"
           style="width:100%;max-width:700px;border-radius:15px;border:2px solid #2ecc71;box-shadow:0 4px 20px rgba(46,204,113,0.3)">
    </a>
  </div>
  <h2 style="color:#2ecc71;margin:0 0 5px 0;font-size:24px">&#x1F6A9; शिव AI (Shiv AI) v2.0</h2>
  <p style="color:#aaa;font-size:13px;margin:0 0 20px 0">by <span style="color:#2ecc71;font-weight:bold">श्री राम नाग</span> &nbsp;|&nbsp; PAISAWALA Channel</p>
  <div style="display:flex;justify-content:center;gap:15px;flex-wrap:wrap;margin-bottom:25px">
    <a href="https://www.youtube.com/@PAISAWALA20" target="_blank"
       style="background:linear-gradient(135deg,#ff0000,#cc0000);color:white;padding:12px 28px;text-decoration:none;font-size:15px;font-weight:bold;border-radius:10px;display:inline-flex;align-items:center;gap:8px;box-shadow:0 4px 15px rgba(255,0,0,0.4)">
      &#x25B6; Subscribe करें
    </a>
    <a href="https://github.com/shriramnag/Aivoicebox" target="_blank"
       style="background:linear-gradient(135deg,#2b3137,#1a1e22);color:white;padding:12px 28px;text-decoration:none;font-size:15px;font-weight:bold;border-radius:10px;display:inline-flex;align-items:center;gap:8px;box-shadow:0 4px 15px rgba(0,0,0,0.4);border:1px solid #30363d">
      &#x1F4BB; GitHub Setup
    </a>
    <a href="https://huggingface.co/Shriramnag/My-Shriram-Voice" target="_blank"
       style="background:linear-gradient(135deg,#ff9500,#e67e00);color:white;padding:12px 28px;text-decoration:none;font-size:15px;font-weight:bold;border-radius:10px;display:inline-flex;align-items:center;gap:8px;box-shadow:0 4px 15px rgba(255,149,0,0.4)">
      &#x1F917; HuggingFace
    </a>
  </div>
  <hr style="border:0;height:1px;background:linear-gradient(90deg,transparent,#2ecc71,transparent);margin-bottom:20px">
  <div style="background:#161b22;color:#e0e0e0;padding:18px 20px;border-radius:12px;border-left:5px solid #ff4444;text-align:left;font-size:14px;line-height:1.8;max-width:680px;margin:0 auto">
    <div style="color:#ff4444;font-size:16px;font-weight:bold;margin-bottom:8px">&#x26A0;&#xFE0F; आवश्यक सूचना — Disclaimer</div>
    यह टूल केवल <b style="color:#2ecc71">Educational Purpose</b> के लिए बनाया गया है।<br>
    किसी की <b>अनुमति के बिना</b> आवाज़ का उपयोग करना <b style="color:#ff4444">कानूनन अपराध है।</b><br><br>
    &#x2705; केवल <b>अपनी आवाज़</b> या अनुमति प्राप्त आवाज़ उपयोग करें।<br>
    &#x26A0;&#xFE0F; गलत उपयोग की जिम्मेदारी <b>यूजर की होगी।</b><br>
    &#x1F4FA; अधिक जानकारी: <a href="https://www.youtube.com/@PAISAWALA20" target="_blank" style="color:#ff4444;font-weight:bold">@PAISAWALA20</a>
  </div>
  <p style="color:#555;font-size:11px;margin-top:18px;margin-bottom:0">
    &#x1F6A9; Shiv AI v2.0 &nbsp;|&nbsp; Made with &#x2764; by श्री राम नाग &nbsp;|&nbsp;
    <a href="https://www.youtube.com/@PAISAWALA20" target="_blank" style="color:#2ecc71">@PAISAWALA20</a>
  </p>
</div>'''

display(HTML(html_code))

# %%
#@title 🔋 Step 1: Anti-Disconnect (पहले यह चलाएं)
from IPython.display import HTML, display

js = '''
<script>
function keepAlive(){
  var btn = document.querySelector('colab-toolbar-button#connect');
  if(btn){ btn.click(); console.log('alive: ' + new Date().toLocaleTimeString()); }
}
setInterval(keepAlive, 55000);
</script>
'''
display(HTML(js))
print('✅ Anti-Sleep Active! हर 55 सेकंड में auto-click होगा।')

# %%
#@title 🚀 Step 2: Setup & Launch (GPU जरूरी है)
import os

print('📁 Repo clone हो रहा है...')
# %cd /content
# !rm -rf Shiv-AI-Voice
# !git clone https://github.com/shriramnag/Shiv-AI-Voice.git
# %cd Shiv-AI-Voice

print('\n⏳ Libraries install हो रही हैं... (3-5 मिनट)')
# !pip install -q --upgrade coqui-tts gradio huggingface_hub pydub scipy numpy
# !apt-get install -y -q ffmpeg

print('\n✅ Ready! Shiv AI launch हो रहा है...')
print('🔗 नीचे Gradio Public URL आएगा — उसे खोलें')
# !python app.py
