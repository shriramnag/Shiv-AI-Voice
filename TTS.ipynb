# %%
#@title Shiv AI v3.5 - Dashboard
from IPython.display import HTML, display
display(HTML("""<div style="background:#0d1117;padding:28px 24px;border-radius:18px;border:2px solid #2ecc71;font-family:Arial,sans-serif;max-width:760px;margin:0 auto"><div style="text-align:center;margin-bottom:18px"><a href="https://www.youtube.com/@PAISAWALA20" target="_blank"><img src="https://raw.githubusercontent.com/shriramnag/Shiv-AI-Voice/main/IMG_20260307_091759.jpg" style="width:100%;max-width:720px;border-radius:14px;border:2px solid #2ecc71"></a></div><div style="text-align:center;margin-bottom:18px"><h2 style="color:#2ecc71;font-size:22px">&#x1F6A9; Shiv AI v3.5</h2><p style="color:#888;font-size:13px">by Shri Ram Nag | PAISAWALA Channel</p></div><div style="display:flex;justify-content:center;gap:12px;flex-wrap:wrap;margin-bottom:20px"><a href="https://www.youtube.com/@PAISAWALA20" target="_blank" style="background:linear-gradient(135deg,#ff0000,#cc0000);color:#fff;padding:11px 26px;text-decoration:none;font-size:14px;font-weight:bold;border-radius:10px">&#x25B6; Subscribe</a><a href="https://github.com/shriramnag/Shiv-AI-Voice" target="_blank" style="background:linear-gradient(135deg,#2b3137,#1a1e22);color:#fff;padding:11px 26px;text-decoration:none;font-size:14px;font-weight:bold;border-radius:10px;border:1px solid #30363d">&#x1F4BB; GitHub</a><a href="https://huggingface.co/Shriramnag/My-Shriram-Voice" target="_blank" style="background:linear-gradient(135deg,#ff9500,#e06d00);color:#fff;padding:11px 26px;text-decoration:none;font-size:14px;font-weight:bold;border-radius:10px">&#x1F917; HuggingFace</a></div><hr style="border:0;height:1px;background:linear-gradient(90deg,transparent,#2ecc71,transparent);margin-bottom:18px"><div style="background:#161b22;color:#e0e0e0;padding:16px 20px;border-radius:12px;border-left:5px solid #ff4444;font-size:13px;line-height:1.9"><div style="color:#ff4444;font-size:15px;font-weight:bold;margin-bottom:8px">&#x26A0; Disclaimer</div>Yah tool sirf <b style="color:#2ecc71">Educational Purpose</b> ke liye hai. Galat upyog ki zimmedari user ki hogi.</div><p style="text-align:center;color:#444;font-size:11px;margin-top:16px">Shiv AI v3.5 | <a href="https://www.youtube.com/@PAISAWALA20" target="_blank" style="color:#2ecc71">@PAISAWALA20</a></p></div>"""))

# %%
#@title Step 1: Anti-Disconnect (pehle chalayein)
from IPython.display import HTML, display
display(HTML("""<script>
function keepAlive(){
  var b = document.querySelector("colab-toolbar-button#connect");
  if(b){ b.click(); }
}
setInterval(keepAlive, 50000);
</script>"""))
print("Anti-Sleep active! Har 50 second mein click hoga.")

# %%
#@title Step 2: Full Setup (ek baar chalayein)
import os
import torch

# GPU check
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("WARNING: GPU nahi mila.")
    print("Runtime > Change runtime type > T4 GPU select karo")

print("Repo clone ho raha hai...")
# %cd /content
# !rm -rf Shiv-AI-Voice
# !git clone https://github.com/shriramnag/Shiv-AI-Voice.git
# %cd Shiv-AI-Voice

print("Libraries install ho rahi hain... (4-6 min)")
# !pip install -q --upgrade coqui-tts gradio huggingface_hub pydub scipy numpy soundfile
# !pip install -q librosa
# !apt-get install -y -q ffmpeg

print("Setup complete! Shiv AI v3.5 launch ho raha hai...")
print("Niche Gradio Public URL aayega - woh browser mein kholein")
print("NOTE: 20-40 min audio ke liye GPU zaroori hai")
# !python app.py
